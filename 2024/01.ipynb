# %% [markdown]
# ## Advent of Code 2024, day1
#
# Throughout the Chief's office, the historically significant locations are listed not by name but by a unique number called the location ID. To make sure they don't miss anything, The Historians split into two groups, each searching the office and trying to create their own complete list of location IDs.
#
# There's just one problem: by holding the two lists up side by side (your puzzle input), it quickly becomes clear that the lists aren't very similar. Maybe you can help The Historians reconcile their lists?
#
# For example:
# ```
# 3   4
# 4   3
# 2   5
# 1   3
# 3   9
# 3   3
# ```
# Maybe the lists are only off by a small amount! To find out, pair up the numbers and measure how far apart they are. Pair up the smallest number in the left list with the smallest number in the right list, then the second-smallest left number with the second-smallest right number, and so on.
#
# Within each pair, figure out how far apart the two numbers are; you'll need to add up all of those distances. For example, if you pair up a 3 from the left list with a 7 from the right list, the distance apart is 4; if you pair up a 9 with a 3, the distance apart is 6.
#
# In the example list above, the pairs and distances would be as follows:
#
# The smallest number in the left list is 1, and the smallest number in the right list is 3. The distance between them is 2.
# The second-smallest number in the left list is 2, and the second-smallest number in the right list is another 3. The distance between them is 1.
# The third-smallest number in both lists is 3, so the distance between them is 0.
# The next numbers to pair up are 3 and 4, a distance of 1.
# The fifth-smallest numbers in each list are 3 and 5, a distance of 2.
# Finally, the largest number in the left list is 4, while the largest number in the right list is 9; these are a distance 5 apart.
# To find the total distance between the left list and the right list, add up the distances between all of the pairs you found. In the example above, this is 2 + 1 + 0 + 1 + 2 + 5, a total distance of 11!
#
# Your actual left and right lists contain many location IDs. What is the total distance between your lists?

# %%
samp = """3   4
4   3
2   5
1   3
3   9
3   3"""

# %%
inp = samp.splitlines()
inp
# Out:
# ['3   4', '4   3', '2   5', '1   3', '3   9', '3   3']

# %%
[x.split() for x in inp]
# Out:
# [['3', '4'], ['4', '3'], ['2', '5'], ['1', '3'], ['3', '9'], ['3', '3']]

# %% [markdown]
# How can I zip the lists so that the result are 2 lists - first containing a first item and the second one containing second items from the tuples?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You can use `zip()` with the unpacking operator `*` to transpose your list of pairs! Here's how:
#
# ```python
# left, right = zip(*[x.split() for x in inp])
# ```
#
# This will give you two tuples: `left` containing all the first items, and `right` containing all the second items.
#
# Want to try it out and see what you get?

# %%
left, right = zip(*[x.split() for x in inp])
print(left)
print(right)
# Out:
# ('3', '4', '2', '1', '3', '3')
# ('4', '3', '5', '3', '9', '3')

# %%
s = sorted(list(map(int, left)))
s
# Out:
# [1, 2, 3, 3, 3, 4]

# %%
def convert(t):
    return list(map(int, t))

convert(right)
# Out:
# [4, 3, 5, 3, 9, 3]

# %% [markdown]
# I want to use a zip-like function where I can pass a custom function. How can I do that?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You can use `map()` for this! It applies a function to corresponding elements from multiple iterables, similar to how `zip()` pairs them up.
#
# For example, if you want to apply a function to pairs of elements from two lists:
#
# ```python
# result = list(map(your_function, left, right))
# ```
#
# Or if you want to compute the absolute difference between sorted pairs:
#
# ```python
# result = list(map(lambda a, b: abs(a - b), sorted_left, sorted_right))
# ```
#
# What operation do you want to perform on the paired elements?

# %%
sorted_left = sorted(convert(left))
sorted_right = sorted(convert(right))
result = list(map(lambda a, b: abs(a - b), sorted_left, sorted_right))
result
# Out:
# [2, 1, 0, 1, 2, 5]

# %%
def solve1a(lines):
    left, right = zip(*[x.split() for x in lines])

    sorted_left = sorted(convert(left))
    sorted_right = sorted(convert(right))

    result = list(map(lambda a, b: abs(a - b), sorted_left, sorted_right))
    return sum(result)

solve1a(samp.splitlines())
# Out:
# 11

# %%
from aocd import get_data
inp = get_data(day=1, year=2024)
inp[:50]
# Out:
# '31594   93577\n46608   24099\n78052   70524\n52680   '

# %%
lines = inp.splitlines()
solve1a(lines)
# Out:
# 1320851

# %% [markdown]
# ## Part 2

# %%
right
# Out:
# ('4', '3', '5', '3', '9', '3')

# %% [markdown]
# How can I get frequencies of the items in the list?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You can use `Counter` from the `collections` module:
#
# ```python
# from collections import Counter
# freq = Counter(right)
# ```
#
# This gives you a dictionary-like object where keys are the items and values are their counts.
#
# Want to try it out?

# %%
from collections import Counter
freq = Counter(convert(right))
freq
# Out:
# Counter({3: 3, 4: 1, 5: 1, 9: 1})

# %%
[x * freq[x] for x in convert(left)]
# Out:
# [9, 4, 0, 0, 9, 9]

# %%
def solve1b(lines):
    left, right = zip(*[x.split() for x in lines])
    freq = Counter(convert(right))
    result = map(lambda x: x * freq[x], convert(left))
    return sum(result)

solve1b(samp.splitlines())
# Out:
# 31

# %%
solve1b(inp.splitlines())
# Out:
# 26859182
