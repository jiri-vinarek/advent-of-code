# %% [markdown]
# # --- Day 10: Factory ---
#
# The Elves do have the manual for the machines, but the section detailing the initialization procedure was eaten by a Shiba Inu. All that remains of the manual are some indicator light diagrams, button wiring schematics, and joltage requirements for each machine.
#
# For example:
# ```
# [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
# [...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
# [.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}
# ```
# The manual describes one machine per line. Each line contains a single indicator light diagram in [square brackets], one or more button wiring schematics in (parentheses), and joltage requirements in {curly braces}.
#
# To start a machine, its indicator lights must match those shown in the diagram, where . means off and # means on. The machine has the number of indicator lights shown, but its indicator lights are all initially off.
#
# So, an indicator light diagram like [.##.] means that the machine has four indicator lights which are initially off and that the goal is to simultaneously configure the first light to be off, the second light to be on, the third to be on, and the fourth to be off.
#
# You can toggle the state of indicator lights by pushing any of the listed buttons. Each button lists which indicator lights it toggles, where 0 means the first light, 1 means the second light, and so on. When you push a button, each listed indicator light either turns on (if it was off) or turns off (if it was on). You have to push each button an integer number of times; there's no such thing as "0.5 presses" (nor can you push a button a negative number of times).
#
# So, a button wiring schematic like (0,3,4) means that each time you push that button, the first, fourth, and fifth indicator lights would all toggle between on and off. If the indicator lights were [#.....], pushing the button would change them to be [...##.] instead.
#
# Because none of the machines are running, the joltage requirements are irrelevant and can be safely ignored.
#
# You can push each button as many times as you like. However, to save on time, you will need to determine the fewest total presses required to correctly configure all indicator lights for all machines in your list.
#
# There are a few ways to correctly configure the first machine:
#
# ```
# [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
# ```
# - You could press the first three buttons once each, a total of 3 button presses.
# - You could press (1,3) once, (2,3) once, and (0,1) twice, a total of 4 button presses.
# - You could press all of the buttons except (1,3) once each, a total of 5 button presses.
#
# However, the fewest button presses required is 2. One way to do this is by pressing the last two buttons ((0,2) and (0,1)) once each.
#
# The second machine can be configured with as few as 3 button presses:
# ```
# [...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
# ```
# One way to achieve this is by pressing the last three buttons ((0,4), (0,1,2), and (1,2,3,4)) once each.
#
# The third machine has a total of six indicator lights that need to be configured correctly:
# ```
# [.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}
# ```
# The fewest presses required to correctly configure it is 2; one way to do this is by pressing buttons (0,3,4) and (0,1,2,4,5) once each.
#
# So, the fewest button presses required to correctly configure the indicator lights on all of the machines is 2 + 3 + 2 = 7.
#
# Analyze each machine's indicator light diagram and button wiring schematics. What is the fewest button presses required to correctly configure the indicator lights on all of the machines?

# %%
from fastcore.utils import L
from aocd import get_data

inp = get_data(day=10, year=2025)
samp = '''[.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
[...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
[.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}'''
samp

# %% [markdown]
# Summarize the problem for me.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# This is a puzzle about configuring indicator lights on machines by pressing buttons!
#
# **The setup:**
# - Each machine has indicator lights (initially all OFF)
# - You have a target configuration showing which lights should be ON (#) or OFF (.)
# - You have buttons that toggle specific lights when pressed
# - Goal: Find the minimum number of button presses needed
#
# **Key mechanics:**
# - Each button toggles a specific set of lights (ON→OFF or OFF→ON)
# - You can press each button any number of times (0, 1, 2, ...)
# - You need to find the fewest total presses across all buttons to reach the target
#
# **The task:**
# Parse each machine's configuration and find the minimum button presses for each machine, then sum them all up.
#
# **Example:** The first machine `[.##.]` needs lights in pattern OFF-ON-ON-OFF. By pressing buttons `(0,2)` and `(0,1)` once each (2 total presses), you can achieve this.
#
# This is essentially a system of linear equations over GF(2) (binary field) - each light needs to be toggled an odd or even number of times to reach its target state.
#
# Would you like to start parsing the input, or discuss the solving approach first?

# %%
xs = samp.splitlines()
xs

# %%
x = xs[0]
x

# %%
import regex

# %%
lights_s, button_s, joltage_s = regex.match(r'\[(.*)\](.*)\{(.*)\}', x).groups()
lights_s, button_s, joltage_s

# %%
bs = regex.findall(r'(\d+,\d+)', button_s)
bs

# %%
b = bs[0]
b

# %%
L(b.split(',')).map(int)

# %%
def parse_ints(s):
    return L(s.split(',')).map(int)
parse_ints(b)

# %%
L(bs).map(parse_ints)

# %%
L(list(lights_s)).map(lambda c: 1 if c=='#' else 0)

# %% [markdown]
# Wrap the code above into a parse function
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here's a parse function that wraps the code you've written:
#
# ```python
# def parse_machine(line):
#     lights_s, button_s, joltage_s = regex.match(r'\[(.*)\](.*)\{(.*)\}', line).groups()
#     target = L(list(lights_s)).map(lambda c: 1 if c=='#' else 0)
#     buttons = L(regex.findall(r'\([\d,]+\)', button_s)).map(lambda b: parse_ints(b.strip('()')))
#     return target, buttons
# ```
#
# This extracts the target light configuration and the button definitions. Would you like me to test it on the sample data, or would you prefer to try it yourself?

# %%
def parse_machine(line):
    lights_s, button_s, joltage_s = regex.match(r'\[(.*)\](.*)\{(.*)\}', line).groups()
    lights = L(list(lights_s)).map(lambda c: 1 if c=='#' else 0)
    buttons = L(regex.findall(r'\([\d,]+\)', button_s)).map(lambda b: parse_ints(b.strip('()')))
    joltage = parse_ints(joltage_s)
    return lights, buttons, joltage
parse_machine(x)

# %%
ls, bs, js = parse_machine(x)

# %% [markdown]
# Where we are at?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# You've successfully built a parser! For the first sample machine, you get:
# - **Target lights:** `[0,1,1,0]` — need lights 1 and 2 ON (0-indexed)
# - **Buttons:** 6 buttons, each toggling specific lights
# - **Joltage:** ignored for Part 1
#
# **Next step:** Solve for the minimum button presses. Since each button press toggles lights (XOR operation), and pressing a button twice cancels out, this is a linear algebra problem over GF(2) — each button is either pressed 0 or 1 times.
#
# The challenge: among all valid solutions, find the one with the fewest total presses (fewest 1s in the solution vector).
#
# How would you like to approach the solving part — brute force for small cases, or go straight to a more general linear algebra approach?

# %% [markdown]
# I can represent a button press like a list of lights it turns on/off (1) or those it doesn't affect (0).
# Then, I can represent it as an equation, for example:
# ```
# [0, 1, 1, 0] = a*[0, 0, 0, 1] xor b*[0, 1, 0, 1] xor c*[0, 0, 1, 0] xor d*[0, 0, 1, 1] xor e*[1, 0, 1, 0] xor f*[1, 1, 0, 0]
# ```
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Exactly right! You've set up the problem beautifully. Each variable (a, b, c, d, e, f) is either 0 or 1 — representing whether you press that button or not.
#
# In GF(2) (binary field), XOR is addition and multiplication is AND. So your equation becomes a system of linear equations mod 2:
#
# ```
# Light 0:  0 = 0a + 0b + 0c + 0d + 1e + 1f  →  e + f ≡ 0 (mod 2)
# Light 1:  1 = 0a + 1b + 0c + 0d + 0e + 1f  →  b + f ≡ 1 (mod 2)
# Light 2:  1 = 0a + 0b + 1c + 1d + 1e + 0f  →  c + d + e ≡ 1 (mod 2)
# Light 3:  0 = 1a + 1b + 0c + 1d + 0e + 0f  →  a + b + d ≡ 0 (mod 2)
# ```
#
# The twist: there may be multiple solutions, and you want the one with minimum **weight** (fewest 1s, i.e., fewest button presses).
#
# How would you like to find solutions — brute force over all 2^6 combinations, or use Gaussian elimination to find the solution space first?

# %% [markdown]
# Let's use the elimination.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great choice! For Gaussian elimination over GF(2), you'll need to:
#
# 1. **Build the matrix:** Each column is a button's effect vector, and the target is your RHS
# 2. **Row reduce:** Same as regular Gaussian elimination, but all arithmetic is mod 2 (so 1+1=0)
# 3. **Find solutions:** Free variables give you multiple solutions — enumerate them to find minimum weight
#
# First step: can you build the augmented matrix from your parsed data? You'd want something like:
#
# ```
# | e  f  b  ...  | target |
# | 0  1  0  ...  |   0    |  ← light 0
# | 0  1  1  ...  |   1    |  ← light 1
# ...
# ```
#
# Each row is a light, each column (except last) is a button. Want to try constructing that matrix?

# %%
b = bs[1]
b

# %%
[1 if i in b else 0 for i in range(4)]

# %%
def effect_vector(b, light_cnt):
    return [1 if i in b else 0 for i in range(light_cnt)]
effect_vector(b, 4)

# %%
bs.map(effect_vector, light_cnt=len(ls))

# %%
def all_effect_vectors(bs, light_cnt):
    return bs.map(effect_vector, light_cnt=light_cnt)
es = all_effect_vectors(bs, len(ls))
es

# %% [markdown]
# Does NumPy or similar library have a function for the Gaussian elimination?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# NumPy doesn't have a built-in function specifically for Gaussian elimination over GF(2). However, you have a few options:
#
# 1. **Write your own:** It's straightforward — swap rows, use XOR for row operations (just `^` in Python for integers)
# 2. **Use `sympy`:** It has `Matrix.rref()` that can work with modular arithmetic
# 3. **Use `numpy` with mod 2:** Do regular Gaussian elimination but apply `% 2` after each operation
#
# Since you're working over GF(2), writing a simple version yourself might be clearest and give you the most control. It's only about 10-20 lines of code.
#
# Which approach appeals to you?

# %% [markdown]
# Let's implement it ourselves.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Let's break it down into steps:
#
# 1. **Build the augmented matrix:** Combine effect vectors (as columns) with the target vector
# 2. **Forward elimination:** For each pivot column, find a row with a 1, swap if needed, then XOR that row into all other rows with a 1 in that column
# 3. **Back substitution:** (Often combined with step 2 if you do full row reduction)
#
# First, you'll want to transpose your effect vectors so buttons become columns and lights become rows, then append the target as the last column.
#
# Can you build the augmented matrix from `es` and `ls`? Something like:
#
# ```python
# import numpy as np
# A = np.array(es).T  # transpose so rows = lights
# # then add ls as the rightmost column
# ```
#
# Give that a try?

# %%
import numpy as np
A = np.array(es).T  # transpose so rows = lights
A
# then add ls as the rightmost column

# %% [markdown]
# How can I add an extra column to a numpy matrix?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You can use `np.column_stack()` or `np.c_[]`:
#
# ```python
# # Option 1:
# augmented = np.column_stack([A, ls])
#
# # Option 2:
# augmented = np.c_[A, ls]
# ```
#
# Both will add `ls` as the rightmost column to matrix `A`. Try one and see what you get!

# %%
import numpy as np
A = np.array(es).T  # transpose so rows = lights
A = np.column_stack([A, ls])
A

# %% [markdown]
# Ok, what next?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Now you have your augmented matrix where the last column is your target.
#
# Next step: **Gaussian elimination over GF(2)**. You'll iterate through each column (except the last one) and:
# - Find a row with a 1 in that column (if it exists)
# - Swap it to be the pivot row
# - XOR that row into all other rows that have a 1 in that column
#
# Start with a function that takes your matrix and performs row reduction. You'll need operations like:
# - `A[i] ^ A[j]` to XOR two rows
# - `A[[i, j]] = A[[j, i]]` to swap rows
#
# Want to try writing the elimination loop, or would you like me to sketch out the structure first?

# %% [markdown]
# Can I sort the rows somehow?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes! You can sort rows in NumPy using `A[indices]` where `indices` is the order you want.
#
# For Gaussian elimination, you don't typically sort all rows at once. Instead, for each column you're working on, you find a row with a 1 in that position and swap it to the current pivot position.
#
# Are you thinking of sorting to make the pivot-finding easier, or do you have a different strategy in mind?

# %% [markdown]
# Yes, I wanted to sort them to make the pivot-finding easier.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# That's a creative idea! You could sort rows to group ones with 1s in earlier columns at the top, which might reduce swaps.
#
# However, there's a catch: as you perform XOR operations during elimination, the row values change, so your initial sort order might not stay optimal.
#
# The standard approach is simpler: for each column, just scan downward from the current row to find any row with a 1 in that column, then swap. It's just a few lines:
#
# ```python
# # Find a pivot for column col starting from row start
# for row in range(start, num_rows):
#     if A[row, col] == 1:
#         # Swap rows
#         break
# ```
#
# Does that approach make sense, or would you still like to explore sorting?

# %% [markdown]
# No, this makes sense.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great! So now you can start writing the elimination function.
#
# Try writing a loop that goes through each column (except the last one), finds a pivot row with a 1, swaps it into position, and then XORs it with other rows that have a 1 in that column.
#
# Want to give it a shot?

# %%
# Find a pivot for column col starting from row start
col = 0
start = 0
num_rows = len(A)
for row in range(start, num_rows):
    if A[row, col] == 1:
        # Swap rows
        A[[start, row]] = A[[row, start]]
        break

# %%
A

# %%
def find_pivot(A, col, start):
    A = A.copy()
    # Find a pivot for column col starting from row start
    num_rows = len(A)
    for row in range(start, num_rows):
        if A[row, col] == 1:
            # Swap rows
            A[[start, row]] = A[[row, start]]
            return A
    return None
A1 = find_pivot(A, 0, 0)
A1

# %% [markdown]
# What's next?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good! Now you've swapped the pivot row into position.
#
# Next step: XOR the pivot row with all other rows that have a 1 in that same column. This eliminates the 1s above and below the pivot.
#
# Try adding a loop after your swap that goes through all rows (except the pivot row itself) and XORs them if they have a 1 in column `col`.

# %%
col = 0
pivot_row = 0
num_rows = len(A1)
for row in range(pivot_row + 1, num_rows):
    if A1[row, col] == 1:
        # XOR the pivot row with the current one
        A1[row] ^= A1[pivot_row]
A1

# %% [markdown]
# Wrap the code above into eliminate function
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here's a function that wraps your elimination logic:
#
# ```python
# def eliminate(A, col, pivot_row):
#     A = A.copy()
#     num_rows = len(A)
#     for row in range(num_rows):
#         if row != pivot_row and A[row, col] == 1:
#             A[row] ^= A[pivot_row]
#     return A
# ```
#
# Note: I included rows *above* the pivot too (not just below) — this does full reduction in one pass.
#
# Want to test it on your matrix?

# %%
def reduce_column(A, col, pivot_row):
    A = A.copy()
    num_rows = len(A)
    for row in range(num_rows):
        if row != pivot_row and A[row, col] == 1:
            A[row] ^= A[pivot_row]
    return A

# %%
A2 = reduce_column(A1, 0, 0)
A2

# %% [markdown]
# What's next?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Now combine `find_pivot` and `reduce_column` into a loop that processes all columns!
#
# You'll iterate through each column (except the last), find and swap the pivot, then eliminate. Keep track of which row to start searching from (it increments each time you find a pivot).
#
# Want to try writing that main loop?

# %%
def eliminate(A):
    start = 0
    for c in range(A.shape[1] - 1):
        new = find_pivot(A, c, start)
        if new is not None:
            A = new
            A = reduce_column(A, c, start)
            start +=1
    return A
A3 = eliminate(A)
A3

# %% [markdown]
# How can I finish the function above?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great progress! Your matrix is now in reduced row echelon form (RREF).
#
# Now you need to extract solutions. Looking at your result:
# - Columns 0, 1, 2, 4 have pivots (leading 1s)
# - Columns 3, 5 are **free variables** (no pivots)
# - The last column is your target
#
# To find all solutions, you enumerate all combinations of the free variables (0 or 1 for each), then read off the corresponding values for pivot variables from the RREF.
#
# Does that make sense? Want to try identifying which columns are free variables first?

# %% [markdown]
# I can find the free variables using a for loop. Is there some trick to do that using numpy?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Yes! You can identify pivot columns by checking which columns have a leading 1 in each row:
#
# ```python
# pivot_cols = []
# for row in range(len(A3)):
#     for col in range(A3.shape[1] - 1):  # exclude last column
#         if A3[row, col] == 1:
#             pivot_cols.append(col)
#             break
# ```
#
# Then free variables are the columns NOT in `pivot_cols`. You could use set operations:
#
# ```python
# all_cols = set(range(A3.shape[1] - 1))
# free_cols = all_cols - set(pivot_cols)
# ```
#
# Want to try that approach?

# %%
pivot_cols = []
for row in range(len(A3)):
    for col in range(A3.shape[1] - 1):  # exclude last column
        if A3[row, col] == 1:
            pivot_cols.append(col)
            break

# %%
all_cols = set(range(A3.shape[1] - 1))
free_cols = all_cols - set(pivot_cols)
free_cols

# %% [markdown]
# What's next?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! Columns 3 and 5 are free variables (buttons you can choose to press or not).
#
# Now enumerate all 2^2 = 4 combinations of values for these free variables (00, 01, 10, 11), and for each combination:
# 1. Set those free variable values
# 2. Read the pivot variable values from the RREF using back substitution
# 3. Count the total number of 1s (button presses)
# 4. Keep track of the minimum
#
# Want to try writing code to enumerate the free variable combinations?

# %%
free_col_vals = list(product([0, 1], repeat=2))
free_col_vals

# %%
L(free_col_vals).map(lambda t: L(free_cols, t).zip())

# %%
fs = L(free_col_vals).map(lambda t: dict(L(free_cols, t).zip()))
fs

# %%
f = fs[0]
f

# %% [markdown]
# Wheare are we at?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# You've got all combinations of free variable assignments as dictionaries!
#
# **Next step:** For each combination, construct the full solution vector:
# 1. Start with a solution vector of the right length (6 buttons)
# 2. Fill in the free variable values from your dictionary
# 3. For pivot variables, read their values from the RREF (they depend on the free variables and the target)
# 4. Count the 1s in each solution and track the minimum
#
# Want to try writing code to build one complete solution vector from a single free variable assignment, like `{3: 0, 5: 0}`?

# %%
res = np.zeros(A3.shape[1] - 1, int)
res

# %%
for i, v in f.items(): res[i] = v
res

# %% [markdown]
# How can I read the values from the RREF?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good question! For each pivot row in the RREF, you can read off the pivot variable's value.
#
# Looking at row 0 of `A3`:
# ```
# [1, 0, 0, 1, 0, 1, | 1]
# ```
# This means: `button_0 + button_3 + button_5 = 1` (mod 2)
#
# Since you've already set values for buttons 3 and 5 (the free variables), you can solve for button 0:
# ```python
# button_0 = A3[0, -1] ^ res[3] ^ res[5]  # XOR the target with free variable contributions
# ```
#
# You'd do this for each pivot row. Want to try writing a loop that goes through the pivot rows and fills in the pivot variable values?

# %%
button_0 = A3[0, -1] ^ res[3] ^ res[5]  # XOR the target with free variable contributions
button_0

# %% [markdown]
# Do I need to do this in a loop? What about assigning it all at once?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, you can vectorize it! The key insight is that for each pivot row, you're XORing the target with the dot product of that row's free variable columns and their values.
#
# Something like:
#
# ```python
# free_cols_list = list(free_cols)
# contributions = A3[:len(pivot_cols), free_cols_list] @ res[free_cols_list] % 2
# res[pivot_cols] = A3[:len(pivot_cols), -1] ^ contributions
# ```
#
# Want to try that?

# %%
free_cols_list = list(free_cols)
contributions = A3[:len(pivot_cols), free_cols_list] @ res[free_cols_list] % 2
res[pivot_cols] = A3[:len(pivot_cols), -1] ^ contributions
res

# %% [markdown]
# Is this correct?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Let's verify! Your solution is `[1, 1, 1, 0, 0, 0]`, meaning press buttons 0, 1, and 2.
#
# Check it by computing what lights this produces:
# ```python
# result = np.zeros(len(ls), int)
# for i, val in enumerate(res):
#     if val == 1:
#         result ^= np.array(es[i])
# result
# ```
#
# Does this match your target `ls`?

# %%
result = np.zeros(len(ls), int)
for i, val in enumerate(res):
    if val == 1:
        result ^= np.array(es[i])
result

# %% [markdown]
# Help me understand how the vectorized version work. Explain each step clearly.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great! It matches `ls = [0, 1, 1, 0]`, so the solution is correct.
#
# Let me break down the vectorized version step by step:
#
# **Step 1: Get free columns as a list**
# ```python
# free_cols_list = list(free_cols)  # [3, 5]
# ```
#
# **Step 2: Calculate contributions from free variables**
# ```python
# contributions = A3[:len(pivot_cols), free_cols_list] @ res[free_cols_list] % 2
# ```
# - `A3[:len(pivot_cols), free_cols_list]` extracts the sub-matrix showing how free variables affect each pivot row
# - `res[free_cols_list]` gets the values you assigned to free variables (both 0 in this case)
# - `@` does matrix multiplication, giving you the XOR sum of free variable contributions for each row
# - `% 2` ensures binary values
#
# **Step 3: Solve for pivot variables**
# ```python
# res[pivot_cols] = A3[:len(pivot_cols), -1] ^ contributions
# ```
# - `A3[:len(pivot_cols), -1]` is the target value for each pivot row
# - `^ contributions` XORs out the free variable contributions
# - What's left is the value needed for each pivot variable
#
# Does each step make sense now?

# %% [markdown]
# Yes. Please wrap this into a function.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Here's a function that takes the RREF matrix, pivot columns, and free variable assignment, and returns the complete solution:
#
# ```python
# def get_solution(A_rref, pivot_cols, free_cols, free_vals):
#     res = np.zeros(A_rref.shape[1] - 1, int)
#     free_cols_list = list(free_cols)
#
#     # Set free variable values
#     for i, col in enumerate(free_cols_list):
#         res[col] = free_vals[i]
#
#     # Calculate pivot variable values
#     contributions = A_rref[:len(pivot_cols), free_cols_list] @ res[free_cols_list] % 2
#     res[pivot_cols] = A_rref[:len(pivot_cols), -1] ^ contributions
#
#     return res
# ```
#
# Want to test it with your data?

# %%
def get_solution(A_rref, pivot_cols, free_cols, free_vals):
    res = np.zeros(A_rref.shape[1] - 1, int)
    free_cols_list = list(free_cols)
    
    # Set free variable values
    for i, col in enumerate(free_cols_list):
        res[col] = free_vals[i]
    
    # Calculate pivot variable values
    contributions = A_rref[:len(pivot_cols), free_cols_list] @ res[free_cols_list] % 2
    res[pivot_cols] = A_rref[:len(pivot_cols), -1] ^ contributions
    
    return res

# %% [markdown]
# Let's test the function.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Sure! Try calling it with your data:
#
# ```python
# sol = get_solution(A3, pivot_cols, free_cols, (0, 0))
# sol
# ```
#
# This should give you the solution for the first free variable combination. What do you get?

# %%
sol = get_solution(A3, pivot_cols, free_cols, free_col_vals[0])
sol

# %%
sols = L(free_col_vals).map(lambda f: get_solution(A3, pivot_cols, free_cols, f))
sols

# %%
sols.map(sum)

# %%
min(sols.map(sum))

# %% [markdown]
# Where are we at?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Excellent! You've successfully solved the first machine with a minimum of **2 button presses**.
#
# **Current status:**
# - You can parse a machine line
# - Build and solve the linear system over GF(2)
# - Find all solutions and pick the minimum
#
# **Next steps:**
# 1. Wrap everything into a function that takes one machine line and returns the minimum presses
# 2. Apply it to all machines in the input
# 3. Sum up the results
#
# Want to start by wrapping your code into a `solve_machine(line)` function?

# %% [markdown]
# Put the detection of pivot columns into a function and refactor the solve_machine
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# ```python
# def get_pivot_cols(A):
#     pivot_cols = []
#     for row in range(len(A)):
#         for col in range(A.shape[1] - 1):
#             if A[row, col] == 1:
#                 pivot_cols.append(col)
#                 break
#     return pivot_cols
# ```
#
# ```python
# def solve_machine(line):
#     ls, bs, js = parse_machine(line)
#     A = np.column_stack([np.array(all_effect_vectors(bs, len(ls))).T, ls])
#     A_rref = eliminate(A)
#     pivot_cols = get_pivot_cols(A_rref)
#     free_cols = set(range(A_rref.shape[1] - 1)) - set(pivot_cols)
#     free_col_vals = list(product([0, 1], repeat=len(free_cols)))
#     sols = L(free_col_vals).map(lambda f: get_solution(A_rref, pivot_cols, free_cols, f))
#     return min(sols.map(sum))
# ```
#
# ```python
# solve_machine(x)
# ```

# %%
def get_pivot_cols(A):
    pivot_cols = []
    for row in range(len(A)):
        for col in range(A.shape[1] - 1):
            if A[row, col] == 1:
                pivot_cols.append(col)
                break
    return pivot_cols

# %%
def solve_machine(line):
    ls, bs, js = parse_machine(line)
    A = np.column_stack([np.array(all_effect_vectors(bs, len(ls))).T, ls])
    A_rref = eliminate(A)
    pivot_cols = get_pivot_cols(A_rref)
    free_cols = set(range(A_rref.shape[1] - 1)) - set(pivot_cols)
    free_col_vals = list(product([0, 1], repeat=len(free_cols)))
    sols = L(free_col_vals).map(lambda f: get_solution(A_rref, pivot_cols, free_cols, f))
    return int(min(sols.map(sum)))

# %%
solve_machine(x)

# %%
def solve(inp):
    return L(inp.splitlines()).map(solve_machine).sum()
solve(samp)

# %%
solve(inp)

# %% [markdown]
# # --- Part Two ---
#
# All of the machines are starting to come online! Now, it's time to worry about the joltage requirements.
#
# Each machine needs to be configured to exactly the specified joltage levels to function properly. Below the buttons on each machine is a big lever that you can use to switch the buttons from configuring the indicator lights to increasing the joltage levels. (Ignore the indicator light diagrams.)
#
# The machines each have a set of numeric counters tracking its joltage levels, one counter per joltage requirement. The counters are all initially set to zero.
#
# So, joltage requirements like {3,5,4,7} mean that the machine has four counters which are initially 0 and that the goal is to simultaneously configure the first counter to be 3, the second counter to be 5, the third to be 4, and the fourth to be 7.
#
# The button wiring schematics are still relevant: in this new joltage configuration mode, each button now indicates which counters it affects, where 0 means the first counter, 1 means the second counter, and so on. When you push a button, each listed counter is increased by 1.
#
# So, a button wiring schematic like (1,3) means that each time you push that button, the second and fourth counters would each increase by 1. If the current joltage levels were {0,1,2,3}, pushing the button would change them to be {0,2,2,4}.
#
# You can push each button as many times as you like. However, your finger is getting sore from all the button pushing, and so you will need to determine the fewest total presses required to correctly configure each machine's joltage level counters to match the specified joltage requirements.
#
# Consider again the example from before:
# ```
# [.##.] (3) (1,3) (2) (2,3) (0,2) (0,1) {3,5,4,7}
# [...#.] (0,2,3,4) (2,3) (0,4) (0,1,2) (1,2,3,4) {7,5,12,7,2}
# [.###.#] (0,1,2,3,4) (0,3,4) (0,1,2,4,5) (1,2) {10,11,11,5,10,5}
# ```
# Configuring the first machine's counters requires a minimum of 10 button presses. One way to do this is by pressing (3) once, (1,3) three times, (2,3) three times, (0,2) once, and (0,1) twice.
#
# Configuring the second machine's counters requires a minimum of 12 button presses. One way to do this is by pressing (0,2,3,4) twice, (2,3) five times, and (0,1,2) five times.
#
# Configuring the third machine's counters requires a minimum of 11 button presses. One way to do this is by pressing (0,1,2,3,4) five times, (0,1,2,4,5) five times, and (1,2) once.
#
# So, the fewest button presses required to correctly configure the joltage level counters on all of the machines is 10 + 12 + 11 = 33.
#
# Analyze each machine's joltage requirements and button wiring schematics. What is the fewest button presses required to correctly configure the joltage level counters on all of the machines?

# %% [markdown]
# Summarize the part 2 for me.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠
#
# **Part 2 changes:**
# - Instead of toggling lights (binary XOR), buttons now **increment counters** by 1
# - Target is no longer binary — it's specific integer values like `{3,5,4,7}`
# - Goal: find minimum button presses to reach exact joltage values
#
# **Key difference:**
# - Part 1: GF(2) linear algebra (each button pressed 0 or 1 times)
# - Part 2: Regular integer linear algebra (each button pressed 0 or more times)
#
# This becomes a system of linear equations over integers, and you want a non-negative integer solution that minimizes the sum of all button presses. This is essentially an **Integer Linear Programming (ILP)** problem or can be approached with linear algebra if the system has a unique solution.

# %% [markdown]
# Can this be solved as a system of linear equations? Can we easily adapt the solution from part 1?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Yes, it can be a system of linear equations, but over **regular integers** instead of GF(2).
#
# **What carries over:**
# - Building the effect matrix (same structure)
# - The augmented matrix setup
#
# **What changes:**
# - No more `% 2` or XOR — use regular arithmetic
# - Solutions can be any non-negative integers
# - Need to minimize the **sum** of button presses
#
# **The challenge:** If the matrix is square and invertible, you can solve directly. But you need:
# 1. Solutions to be **integers** (not fractions)
# 2. Solutions to be **non-negative** (can't press a button -3 times)
#
# Want to try adapting your matrix setup first and see what `numpy.linalg.solve` gives you for the first example?

# %% [markdown]
# But the matrix is not square - there are free variables. In the first part, I generated all the possible combinations for free variables. How would I do that for part 2?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠🧠
#
# Great observation! In Part 1, free variables were binary (0 or 1), so you could enumerate all 2^n combinations.
#
# In Part 2, free variables can be **any non-negative integer** — that's infinitely many combinations!
#
# This is why Part 2 becomes an **optimization problem**. You have a few options:
#
# 1. **Integer Linear Programming (ILP):** Use a solver like `scipy.optimize.milp` to minimize button presses subject to constraints
# 2. **Check if there are free variables:** If the system is fully determined (no free variables), there's only one solution — just solve and check if it's non-negative integers
# 3. **Parametric approach:** Express solutions in terms of free variables and reason about which values minimize the sum
#
# Which approach interests you? Or would you like to first check if the examples even have free variables?

# %% [markdown]
# Let's use milp
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Great choice! `scipy.optimize.milp` is perfect for this.
#
# **Setup:**
# - **Variables:** Number of times each button is pressed (non-negative integers)
# - **Objective:** Minimize the sum of all button presses
# - **Constraints:** The button presses must produce exactly the target joltage values
#
# The key components you'll need:
# - `c`: coefficient vector for the objective (all 1s, since you want to minimize total presses)
# - `A_eq` and `b_eq`: equality constraints (your effect matrix and target joltages)
# - `integrality`: specify that all variables must be integers
# - `bounds`: each variable ≥ 0
#
# Want to start by setting up the constraint matrix and target for the first example?

# %% [markdown]
# Yes, let's set up the constraint matrix.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Perfect! You already have most of what you need from Part 1.
#
# For the first example, you can reuse:
# - `es` — the effect vectors (which buttons affect which counters)
# - `js` — the joltage targets
#
# Try building:
# ```python
# A_eq = np.array(es).T  # transpose so rows = counters
# b_eq = np.array(js)
# ```
#
# What do you get?

# %%
A_eq = np.array(es).T  # transpose so rows = counters
b_eq = np.array(js)
A_eq, b_eq

# %% [markdown]
# What's next?
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Good! Now set up the objective function and call `milp`:
#
# ```python
# from scipy.optimize import milp, LinearConstraint, Bounds
# import numpy as np
#
# c = np.ones(len(bs))  # minimize sum of button presses
# ```
#
# Then create the constraint and bounds, and call `milp`. Want to try that?

# %%
from scipy.optimize import milp, LinearConstraint, Bounds
import numpy as np

c = np.ones(len(bs))  # minimize sum of button presses
c

# %% [markdown]
# Let's proceed
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# Now create the constraints and bounds, then call `milp`:
#
# ```python
# constraints = LinearConstraint(A_eq, lb=b_eq, ub=b_eq)
# bounds = Bounds(lb=0, ub=np.inf)
# integrality = np.ones(len(bs))  # all variables are integers
#
# result = milp(c, constraints=constraints, bounds=bounds, integrality=integrality)
# ```
#
# Give it a try!

# %%
constraints = LinearConstraint(A_eq, lb=b_eq, ub=b_eq)
bounds = Bounds(lb=0, ub=np.inf)
integrality = np.ones(len(bs))  # all variables are integers

result = milp(c, constraints=constraints, bounds=bounds, integrality=integrality)
result

# %%
LinearConstraint?

# %%
int(result.fun)

# %% [markdown]
# Wrap this into a function for me.
#
# ##### 🤖Reply🤖<!-- SOLVEIT_SEPARATOR_7f3a9b2c -->
#
# 🧠🧠🧠🧠
#
# ```python
# def solve_machine_p2(line):
#     ls, bs, js = parse_machine(line)
#     A_eq = np.array(all_effect_vectors(bs, len(js))).T
#     b_eq = np.array(js)
#     c = np.ones(len(bs))
#     constraints = LinearConstraint(A_eq, lb=b_eq, ub=b_eq)
#     bounds = Bounds(lb=0, ub=np.inf)
#     integrality = np.ones(len(bs))
#     result = milp(c, constraints=constraints, bounds=bounds, integrality=integrality)
#     return int(result.fun)
# ```
#
# Want to test it on the sample data?

# %%
def solve_machine_p2(line):
    ls, bs, js = parse_machine(line)
    A_eq = np.array(all_effect_vectors(bs, len(js))).T
    b_eq = np.array(js)
    c = np.ones(len(bs))
    constraints = LinearConstraint(A_eq, lb=b_eq, ub=b_eq)
    bounds = Bounds(lb=0, ub=np.inf)
    integrality = np.ones(len(bs))
    result = milp(c, constraints=constraints, bounds=bounds, integrality=integrality)
    return int(result.fun)
solve_machine_p2(x)

# %%
def solve2(inp):
    return L(inp.splitlines()).map(solve_machine_p2).sum()
solve2(samp)

# %%
solve2(inp)
